# %% [markdown]
# # This is a test Jupyter notebook

# %% [markdown]
# choose Select Kernel in the upper right corner of the screen and then select your Python environment.

# %% [markdown]
# If your file doesn't display cells but is still showing the solid editor view instead, try closing VS Code and then open your .ipynb file by selecting Open with Code. Then, if Code indicates that the file is in "Restricted Mode", select the Restricted Mode box in the lower-left corner and then select Trust.

# %% [markdown]
# ![select-python-kernel.png](attachment:select-python-kernel.png)

# %% [markdown]
# In Jupyter notebooks environmet, you write code in cells.
# Select a plus button at the top of the file to create a new cell below the current cell.
# You can create a new Code cell or a Markdown cell.
# Drag the cell from the left-hand side to move the cell up or down in relation to the cells around it.
# Use the play button to the left of each cell to run that cell.
# you can select Run All to run every cell in your notebook at once
# you can select the red Interrupt button to force stop the program at any time.

# %%
print("Hello Wrold!")

"Hello World"  # in jupyter, you can print stuff placed in quotation marks without need for print() function
# Out:
# Hello Wrold!
# 'Hello World'

# %%
a = 2 + 2
b = 3
if a > b:
    print("a is bigger than 3")
elif a == b:
    print("a is equal to b")
else:
    print("a is smaller than 3")
# Out:
# a is bigger than 3
